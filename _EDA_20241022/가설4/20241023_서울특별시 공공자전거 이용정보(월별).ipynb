# %%
# 라이브러리 임포트
import os
import pandas as pd
import chardet

# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기

import time

import ExcelFile_Merge as em
import ExcelFile_Read as er
import ExcelFile_EDA as ee

# %% [markdown]
# ---
# ### 서울특별시 공공자전거 이용정보(월별)

# %%
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 이용정보(월별)\\'

# %%
start_time = time.time()
df_parquet_2020 = pd.read_parquet(filepath + '서울특별시 공공자전거 이용정보(월별)_2020' + '.parquet')
df_parquet_2021 = pd.read_parquet(filepath + '서울특별시 공공자전거 이용정보(월별)_2021' + '.parquet')
df_parquet_2022 = pd.read_parquet(filepath + '서울특별시 공공자전거 이용정보(월별)_2022' + '.parquet')
df_parquet_2023 = pd.read_parquet(filepath + '서울특별시 공공자전거 이용정보(월별)_2023' + '.parquet')
df_parquet_2024 = pd.read_parquet(filepath + '서울특별시 공공자전거 이용정보(월별)_2024.1-6' + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 1.6315255165100098

# %%
print(df_parquet_2020.shape)
print(df_parquet_2021.shape)
print(df_parquet_2022.shape)
print(df_parquet_2023.shape)
print(df_parquet_2024.shape)
# Out:
# (948876, 11)
# (1323504, 11)
# (1383442, 11)
# (1246385, 11)
# (613732, 11)

# %% [markdown]
# ### G:\내 드라이브\DataSet\_파킷 파일\서울특별시 공공자전거 대여소별 이용정보(시간대별)

# %%
filepath = 'G:\\내 드라이브\\DataSet\\_파킷 파일\\서울특별시 공공자전거 대여소별 이용정보(시간대별)\\'

# %%
start_time = time.time()
df_parquet_2020 = pd.read_parquet(filepath + '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2020' + '.parquet')
df_parquet_2021 = pd.read_parquet(filepath + '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2021' + '.parquet')
df_parquet_2022 = pd.read_parquet(filepath + '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2022' + '.parquet')
df_parquet_2023 = pd.read_parquet(filepath + '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2023' + '.parquet')
df_parquet_2024 = pd.read_parquet(filepath + '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2024' + '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 107.50150346755981

# %%
print(df_parquet_2020.shape)
print(df_parquet_2021.shape)
print(df_parquet_2022.shape)
print(df_parquet_2023.shape)
print(df_parquet_2024.shape)
# Out:
# (19026024, 12)
# (25421727, 12)
# (36160476, 12)
# (39993697, 12)
# (19369646, 12)

# %%
df_parquet_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19369646 entries, 0 to 19369645
# Data columns (total 12 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   대여일자     object
#  1   대여시간     int64
#  2   대여소번호    int64
#  3   대여소명     object
#  4   대여구분코드   object
#  5   성별       object
#  6   연령대코드    object
#  7   이용건수     int64
#  8   운동량      float64
#  9   탄소량      float64
#  10  이동거리(M)  float64
#  11  이용시간(분)  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 1.7+ GB

# %%
df_parquet_2024.head()
# Out:
#       대여일자  대여소번호             대여소명 대여구분코드    성별 연령대코드  이용건수      운동량    탄소량  \
# 0  2024-01    102  102. 망원역 1번출구 앞    일일권  <NA>   20대    30  1562.85  14.77
# 1  2024-01    102  102. 망원역 1번출구 앞    일일권  <NA>   30대    21  1082.06   9.53
# 2  2024-01    102  102. 망원역 1번출구 앞    일일권  <NA>   40대     4    82.63   0.73
# 3  2024-01    102  102. 망원역 1번출구 앞    일일권  <NA>   50대     3   160.96   1.63
# 4  2024-01    102  102. 망원역 1번출구 앞    일일권  <NA>    기타     4    68.96   0.78
#
#     이동거리(M)  이용시간(분)
# 0  63766.65      547
# 1  41075.31      393
# 2   3178.67       66
# 3   7009.09       44
# 4   3375.82       40

# %% [markdown]
# ---
# ### 결측치 확인

# %%
ee.ss_isnull(df_parquet_2024)
# Out:
#       [컬럼명]   [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  613732             0          0.000000
# 1     대여소번호  613732             0          0.000000
# 2      대여소명  613732             0          0.000000
# 3    대여구분코드  613732             0          0.000000
# 4        성별  418815        194917         31.759302
# 5     연령대코드  613732             0          0.000000
# 6      이용건수  613732             0          0.000000
# 7       운동량  613377           355          0.057843
# 8       탄소량  613377           355          0.057843
# 9   이동거리(M)  613732             0          0.000000
# 10  이용시간(분)  613732             0          0.000000

# %%
df_parquet_2024[df_parquet_2024.isnull()]
# Out:
#         대여일자  대여소번호  대여소명 대여구분코드    성별 연령대코드  이용건수  운동량  탄소량  이동거리(M)  이용시간(분)
# 0       <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 1       <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 2       <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 3       <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 4       <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# ...      ...    ...   ...    ...   ...   ...   ...  ...  ...      ...      ...
# 613727  <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 613728  <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 613729  <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 613730  <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
# 613731  <NA>    NaN  <NA>   <NA>  <NA>  <NA>   NaN  NaN  NaN      NaN      NaN
#
# ...

# %%
df_parquet_2024['성별'].value_counts()
# Out:
# 성별
# M    221594
# F    197123
# m        61
# f        37
# Name: count, dtype: Int64

# %%
df_parquet_2024[df_parquet_2024['성별'].isnull()]
# Out:
#            대여일자  대여소번호               대여소명 대여구분코드    성별 연령대코드  이용건수      운동량  \
# 0       2024-01    102    102. 망원역 1번출구 앞    일일권  <NA>   20대    30  1562.85
# 1       2024-01    102    102. 망원역 1번출구 앞    일일권  <NA>   30대    21  1082.06
# 2       2024-01    102    102. 망원역 1번출구 앞    일일권  <NA>   40대     4    82.63
# 3       2024-01    102    102. 망원역 1번출구 앞    일일권  <NA>   50대     3   160.96
# 4       2024-01    102    102. 망원역 1번출구 앞    일일권  <NA>    기타     4    68.96
# ...         ...    ...                ...    ...   ...   ...   ...      ...
# 613714  2024-06   6173  6173. 서울자동차운전전문학원    정기권  <NA>   20대    34  1384.75
# 613715  2024-06   6173  6173. 서울자동차운전전문학원    정기권  <NA>   30대     5   208.10
# 613716  2024-06   6173  6173. 서울자동차운전전문학원    정기권  <NA>   40대     4   343.41
# 613717  2024-06   6173  6173. 서울자동차운전전문학원    정기권  <NA>   50대     2   280.39
# 613718  2024-06   6173  6173. 서울자동차운전전문학원    정기권  <NA>    기타     2     9.71
#
#           탄소량   이동거리(M)  이용시간(분)
# ...

# %% [markdown]
# ---
# ### 컬럼별 유일값 확인

# %%
ee.ss_value_counts(df_parquet_2024)
# Out:
# ...
# 대여일자
# 2024-05    108840
# 2024-04    108472
# 2024-06    108197
# 2024-03    102804
# 2024-02     95536
# 2024-01     89883
# Name: count, dtype: Int64
# ...
# 대여소번호
# 4217    301
# 502     294
# 207     292
# 583     292
# 3511    291
#        ...
# 4931     44
# 6059     37
# 4335     37
# 4426     27
# 1816      7
# Name: count, Length: 2758, dtype: int64
# ...
# 대여소명
# 4217. 한강공원 망원나들목             301
# 502. 자양(뚝섬한강공원)역 1번출구 앞      294
# 207. 여의나루역 1번출구 앞            292
# 583. 청계천 생태교실 앞              292
# 3511. 응봉역 1번출구               291
#                             ...
# 4931. 디에이치퍼스티어아이파크 124동 앞     44
# 6059. 덕수중학교                   37
# 4335. 인재개발원 배움관               37
# 4426. 천주교 보문동 성당              27
# 1816. 금천폭포공원 앞                 7
# Name: count, Length: 2758, dtype: Int64
# ...
# 대여구분코드
# 정기권         336660
# 일일권         260480
# 일일권(비회원)     16592
# Name: count, dtype: Int64
# ...
# 성별
# M    221594
# F    197123
# m        61
# f        37
# Name: count, dtype: Int64
# ...
# 연령대코드
# ...

# %% [markdown]
# ### 성별 컬럼값 통일 (m -> M, f -> F)

# %%
df_parquet_2024.loc[df_parquet_2024['성별'] == 'm', '성별'] = 'M'
df_parquet_2024.loc[df_parquet_2024['성별'] == 'f', '성별'] = 'F'

# %%
df_parquet_2024['성별'].value_counts()
# Out:
# 성별
# M    221655
# F    197160
# Name: count, dtype: Int64

# %%
df = df_parquet_2021
print(ee.ss_isnull(df))
print(ee.ss_value_counts(df))
# Out:
#       [컬럼명]     [sum]  [sum_isnull]  [mean_isnull(%)]
# 0      대여일자  25421727             0          0.000000
# 1      대여시간  25421727             0          0.000000
# 2     대여소번호  25421727             0          0.000000
# 3      대여소명  25421727             0          0.000000
# 4    대여구분코드  25421727             0          0.000000
# 5        성별  14657620      10764107         42.342155
# 6     연령대코드  25421727             0          0.000000
# 7      이용건수  25421727             0          0.000000
# 8       운동량  25273392        148335          0.583497
# 9       탄소량  25273392        148335          0.583497
# 10  이동거리(M)  25421727             0          0.000000
# 11  이용시간(분)  25421727             0          0.000000
# ...
# 대여일자
# 2021-09-02    208866
# 2021-04-28    182940
# 2021-04-27    137469
# 2021-09-24    115696
# 2021-09-17    114034
#                ...
# 2021-01-08      7679
# 2021-03-04      6599
# 2021-01-07      5350
# 2021-03-01      2750
# 2021-05-16      2213
# ...

# %%
df_parquet_2021.head(5)
# Out:
#          대여일자  대여시간  대여소번호                     대여소명 대여구분코드    성별 연령대코드  이용건수  \
# 0  2021-01-01     0   1347  1347. 길음래미안아파트817동 상가 앞    정기권  None  ~10대   2.0
# 1  2021-01-01     0   1349       1349. 월계2교 버스정류장 앞    정기권  None  ~10대   1.0
# 2  2021-01-01     0   1168        1168. 마곡엠밸리10단지 앞    정기권  None  ~10대   1.0
# 3  2021-01-01     0   2619         2619. 석촌고분역 4번출구    정기권  None  ~10대   1.0
# 4  2021-01-01     0    536          536. 행당역 2번출구 앞    정기권  None  ~10대   1.0
#
#      운동량   탄소량  이동거리(M)  이용시간(분)
# 0  28.90  0.23   992.78     13.0
# 1  34.38  0.26  1127.50     10.0
# 2   0.00  0.00     0.00      7.0
# 3  38.75  0.38  1658.34     14.0
# 4  12.96  0.17   743.88      5.0

# %%
print(df_parquet_2020[df_parquet_2020['대여일자'].isnull()].shape[0])
print(df_parquet_2021[df_parquet_2021['대여일자'].isnull()].shape[0])
print(df_parquet_2022[df_parquet_2022['대여일자'].isnull()].shape[0])  # 618679
print(df_parquet_2023[df_parquet_2023['대여일자'].isnull()].shape[0])
print(df_parquet_2024[df_parquet_2024['대여일자'].isnull()].shape[0])
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
df_parquet_2022[~df_parquet_2022['대여일자'].isnull()]
# Out:
#             대여일자  대여소번호           대여소명  대여구분코드  성별 연령대코드  이용건수     운동량   탄소량  \
# 0        2022-01      3           중랑센터  일일(회원)   M   50대     1    0.00  0.00
# 1        2022-01      3           중랑센터      정기  \N   50대     3   62.44  0.51
# 2        2022-01      3           중랑센터      정기   M   40대     5  106.18  0.73
# 3        2022-01      3           중랑센터      정기   M   50대     2  127.88  1.12
# 4        2022-01      5       상암센터 정비실  일일(회원)   M   40대     8  939.26  8.09
# ...          ...    ...            ...     ...  ..   ...   ...     ...   ...
# 1383437  2022-12   6053  6053. 중부세무서 앞     정기권   M   40대     9  539.73  3.67
# 1383438  2022-12   6053  6053. 중부세무서 앞     정기권   M   50대    11  266.69  2.18
# 1383439  2022-12   6053  6053. 중부세무서 앞     정기권   M   60대     1   18.95  0.13
# 1383440  2022-12   6053  6053. 중부세무서 앞     정기권   M  ~10대     2  109.71  0.87
# 1383441  2022-12   6053  6053. 중부세무서 앞     정기권   M    기타     3   28.50  0.27
#
#           이동거리(M)  이용시간(분)
# ...

# %%
df_parquet_2022[~df_parquet_2022['대여일자'].isnull()]['대여일자'].unique()
# Out:
# array(['2022-01', '2022-07', '2022-08', '2022-09', '2022-10', '2022-11',
#        '2022-12'], dtype=object)
