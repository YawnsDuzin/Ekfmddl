# %%
# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")

# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er

# %%
path_dateset = 'G:/내 드라이브/DataSet/'

# %%
print(em.Extract_Extension('G:/내 드라이브/DataSet/서울특별시 공공자전거 이용정보(일별)/서울특별시 공공자전거 이용정보(일별)_2406.csv'))
print(em.Extract_Filename('G:/내 드라이브/DataSet/서울특별시 공공자전거 이용정보(일별)/서울특별시 공공자전거 이용정보(일별)_2406.csv'))
# Out:
# .csv
# 서울특별시 공공자전거 이용정보(일별)_2406

# %%
path_sub = '서울특별시 공공자전거 대여소별 이용정보(시간대별)/2021/'

# %%
path_sub = '서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2021/'
em.Check_Encoding(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2021/
# file :  tpss_bcycl_od_statnhm_202101.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202102.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202107.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202103.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202111.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202108.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202104.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202106.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202109.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202112.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202105.csv, encoding :  EUC-KR
# file :  tpss_bcycl_od_statnhm_202110.csv, encoding :  EUC-KR

# %%
path_sub = '서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2024/'
em.Check_File(path_dateset, path_sub)
# Out:
# path :  G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2024/
# read_file - file_path :  G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2024/202401.csv , encoding :  EUC-KR
# ...
# .csv, 202401.csv, 3954593
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20240101, '출발시간', 0, 'ST-1093', '중화2동_035_1', 'ST-3168', '중화2동_009_1', 1, 5, 848]
# read_file - file_path :  G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2024/202402.csv , encoding :  EUC-KR
# ...
# .csv, 202402.csv, 3380989
# ['기준_날짜', '집계_기준', '기준_시간대', '시작_대여소_ID', '시작_대여소명', '종료_대여소_ID', '종료_대여소명', '전체_건수', '전체_이용_분', '전체_이용_거리']
# [20240213, '출발시간', 0, 'ST-1046', '성내2동_015_1', 'ST-1092', '풍납2동_026_1', 1, 6, 600]
# read_file - file_path :  G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2024/202403.csv , encoding :  EUC-KR
# ...
# .csv, 202403.csv, 6082585
# ...

# %%
columns = ['기준_날짜', '기준_시간대', '시작_대여소_ID', '종료_대여소_ID', '전체_건수', '전체_이용_분', '전체_이용_거리']
em.Merge_File(path_dateset, path_sub, 'tpss_bcycl_od_statnhm_2023')

# %%
er.Read_pyarrow('G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2022/tpss_bcycl_od_statnhm_2022.csv')
# Out:
#                기준_날짜  기준_시간대 시작_대여소_ID 종료_대여소_ID  전체_건수  전체_이용_분  전체_이용_거리  \
# 0         20220102.0     0.0   ST-1034   ST-2210    1.0     52.0    2770.0
# 1         20220102.0     0.0    ST-105    ST-362    1.0      9.0    1500.0
# 2         20220102.0     0.0   ST-1061   ST-1837    1.0      3.0     570.0
# 3         20220102.0     0.0    ST-108    ST-108    1.0      0.0       0.0
# 4         20220102.0     0.0    ST-108   ST-2546    2.0     62.0    9360.0
# ...              ...     ...       ...       ...    ...      ...       ...
# 77935693         NaN     NaN                        NaN      NaN       NaN
# 77935694         NaN     NaN                        NaN      NaN       NaN
# 77935695         NaN     NaN                        NaN      NaN       NaN
# 77935696         NaN     NaN                        NaN      NaN       NaN
# 77935697         NaN     NaN                        NaN      NaN       NaN
#
#                 기준일자  구분코드   기준시간대  시작대여소ID      시작대여소명  종료대여소ID  \
# ...

# %%
er.Get_ExcelEncoding('G:/내 드라이브/DataSet/서울특별시 공공자전거 이용정보(일별)/서울특별시 공공자전거 이용정보(일별)_2406.csv')
# Out:
# 'EUC-KR'

# %%
path_sub = '서울특별시 공공자전거 대여소별 이용정보(시간대별)/2021/'
em.Check_File(path_dateset, path_sub)

# %%
em.merge2_file(path_dateset, path_sub, '서울특별시 공공자전거 대여소별 이용정보(시간대별)_2021', '')

# %% [markdown]
# ### 서울시 따릉이 대여소별 대여 반납 승객수 정보

# %%
path_sub = '서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2021/'
em.Check_File(path_dateset, path_sub)

# %%
em.Get_ExcelEncoding('G:/내 드라이브/DataSet/서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/2021/tpss_bcycl_od_statnhm_202106.csv')
# Out:
# 'EUC-KR'

# %%
# 서울시 따릉이 대여소별 대여/반납 승객수 정보
years = ['2021', '2022', '2023', '2024']

for year in years:
    path_sub = '서울시 따릉이 대여소별 대여 반납 승객수 정보/월 데이터 통합/' + year + '/'
    try:
        print(path_sub)
        print('tpss_bcycl_od_statnhm_' + year)
        
        em.Merge_File(path_dateset, path_sub, 'tpss_bcycl_od_statnhm_' + year, '')
    except:
        print('Err : ', path_sub)
