# %%
# 라이브러리 임포트
import os
import pandas as pd
import chardet

# 사용자 정의함수 경로 설정
import sys
sys.path.append("G:/내 드라이브/Source/_Custom_Function")
# 사용자 정의함수 불러오기

import time

import ExcelFile_Merge as em
import ExcelFile_Read as er
import ExcelFile_EDA as ee

# %%
start_time = time.time()
df_parquet = pd.read_parquet('G:\\내 드라이브\\DataSet\\_최종 병합 파일\\서울시 자전거 이용시설 통계\\' + '_자전거 통계_2019_2023' + '_pivot' +  '.parquet')
print("read_parquet time :", time.time() - start_time)
# Out:
# read_parquet time : 0.017267942428588867

# %%
df_parquet.head(5)
# Out:
#    자치구  총계 연장(㎞)_2018  총계 연장(㎞)_2019  총계 연장(㎞)_2020  총계 연장(㎞)_2021  \
# 0  강남구           52.6           52.6          89.96          98.55
# 1  강동구           40.8           42.1          71.98          74.11
# 2  강북구            7.0            7.0           8.70           8.70
# 3  강서구           27.9           41.7          76.38          68.31
# 4  관악구           19.5           19.5          29.50          27.73
#
#    총계 연장(㎞)_2022  총계 연장(㎞)_2023  총계 노선(개)_2018  총계 노선(개)_2019  총계 노선(개)_2020  \
# 0         110.49         113.39             27             26             65
# 1          74.44          76.62             33             33             66
# 2           8.70           8.70              3              3              8
# 3          77.06          77.34             34             43             80
# 4          27.73          27.73             15             15             19
#
#    ...  겸용도로(비분리형) 연장(㎞)_2020  겸용도로(비분리형) 연장(㎞)_2021  겸용도로(비분리형) 연장(㎞)_2022  \
# 0  ...                  31.71                  40.76                  47.88
# 1  ...                  39.21                  41.07                  41.07
# 2  ...                   2.97                   2.97                   2.97
# 3  ...                  24.41                  14.70                  14.70
# 4  ...                  19.60                  17.80                  17.80
#
#    겸용도로(비분리형) 연장(㎞)_2023  겸용도로(비분리형) 노선(개)_2018  겸용도로(비분리형) 노선(개)_2019  \
# 0                  48.58                     12                     11
# 1                  42.90                     11                     11
# 2                   2.97                      1                      1
# 3                  14.70                      8                      7
# 4                  17.80                      5                      4
#
#    겸용도로(비분리형) 노선(개)_2020  겸용도로(비분리형) 노선(개)_2021  겸용도로(비분리형) 노선(개)_2022  \
# 0                     29                     32                     39
# 1                     27                     39                     39
# 2                      2                      2                      2
# 3                     14                     11                     11
# 4                      7                      7                      7
#
#    겸용도로(비분리형) 노선(개)_2023
# 0                     40
# 1                     42
# 2                      2
# 3                     11
# 4                      7
#
# [5 rows x 73 columns]

# %%
df_parquet_temp = df_parquet

# %%
df_parquet_temp['총계 연장(㎞)(2023-2022)'] = df_parquet_temp['총계 연장(㎞)_2023'] - df_parquet_temp['총계 연장(㎞)_2022']
df_parquet_temp[['자치구', '총계 연장(㎞)(2023-2022)']].sort_values(by = '총계 연장(㎞)(2023-2022)', ascending = False).head(10)
# Out:
#      자치구  총계 연장(㎞)(2023-2022)
# 6    구로구                 5.07
# 14   서초구                 3.17
# 0    강남구                 2.90
# 17   송파구                 2.23
# 1    강동구                 2.18
# 15   성동구                 1.35
# 19  영등포구                 1.05
# 5    광진구                 1.00
# 13  서대문구                 0.67
# 10  동대문구                 0.62

# %%
df_parquet_temp
# Out:
#      자치구  총계 연장(㎞)_2018  총계 연장(㎞)_2019  총계 연장(㎞)_2020  총계 연장(㎞)_2021  \
# 0    강남구           52.6           52.6          89.96          98.55
# 1    강동구           40.8           42.1          71.98          74.11
# 2    강북구            7.0            7.0           8.70           8.70
# 3    강서구           27.9           41.7          76.38          68.31
# 4    관악구           19.5           19.5          29.50          27.73
# 5    광진구           29.8           29.8          46.80          47.70
# 6    구로구           10.9           10.5          26.54          26.61
# 7    금천구            8.2            8.2           8.86           9.16
# 8    노원구           28.3           28.3          42.88          43.71
# 9    도봉구           12.3           12.3          12.94          12.94
# 10  동대문구           24.3           23.9          37.80          37.70
# 11   동작구           13.4           13.4          13.90          14.30
# 12   마포구           33.4           34.6          65.72          69.40
# 13  서대문구           19.4           19.4          31.10          31.22
# 14   서초구           23.5           29.0          37.39          40.77
# 15   성동구           20.6           19.9          27.20          27.18
# 16   성북구            8.0            7.7           9.80          14.53
# 17   송파구           91.7           92.6          97.08          97.15
# 18   양천구           40.0           41.0          55.52          55.63
# 19  영등포구           36.6           37.0          63.79          63.29
# 20   용산구           22.1           22.7          32.99          32.99
# 21   은평구           26.9           26.9          39.80          44.02
# 22   종로구           23.7           23.7          26.53          31.55
# 23    중구           15.4           15.4          15.30          22.39
# 24   중랑구            6.1            6.6          10.03           9.75
#
#     총계 연장(㎞)_2022  총계 연장(㎞)_2023  총계 노선(개)_2018  총계 노선(개)_2019  총계 노선(개)_2020  \
# 0          110.49         113.39             27             26             65
# 1           74.44          76.62             33             33             66
# 2            8.70           8.70              3              3              8
# 3           77.06          77.34             34             43             80
# 4           27.73          27.73             15             15             19
# 5           48.30          49.30             22             23             50
# 6           27.48          32.55             15             14             38
# 7            9.16           9.16              7              7             19
# 8           43.71          43.99             25             25             40
# 9           12.94          12.94              4              4              8
# 10          37.70          38.32             22             21             30
# 11          14.30          14.30             14             15             17
# 12          67.40          67.40             33             33             57
# 13          31.42          32.09             28             27             47
# 14          41.07          44.24             23             28             44
# 15          27.83          29.18             22             21             31
# 16          16.84          16.84              7              8             13
# 17          97.49          99.72             50             51            186
# 18          56.49          56.49             28             28             59
# 19          63.19          64.24             43             47             82
# 20          32.53          32.53             16             19             26
# 21          44.65          44.65             17             18             30
# 22          32.08          32.08             22             24             38
# 23          22.39          22.39             13             12             18
# 24           9.75           9.75              8              9             16
#
#     ...  겸용도로(비분리형) 연장(㎞)_2021  겸용도로(비분리형) 연장(㎞)_2022  겸용도로(비분리형) 연장(㎞)_2023  \
# 0   ...                  40.76                  47.88                  48.58
# 1   ...                  41.07                  41.07                  42.90
# 2   ...                   2.97                   2.97                   2.97
# 3   ...                  14.70                  14.70                  14.70
# 4   ...                  17.80                  17.80                  17.80
# 5   ...                  30.43                  31.03                  32.03
# 6   ...                  11.66                  11.66                  12.60
# 7   ...                   3.19                   3.19                   3.19
# 8   ...                   8.74                   8.74                   9.59
# 9   ...                  10.51                  10.51                  10.51
# 10  ...                   4.90                   4.90                   4.90
# 11  ...                  12.92                  12.92                  12.92
# 12  ...                   2.14                   2.14                   2.14
# 13  ...                   2.90                   2.90                   2.90
# 14  ...                   4.80                   4.80                   7.27
# 15  ...                  12.47                  12.47                  13.02
# 16  ...                   2.60                   2.60                   2.60
# 17  ...                  12.71                  13.06                  13.27
# 18  ...                  19.24                  22.24                  22.24
# 19  ...                   5.00                   5.00                   5.80
# 20  ...                   5.70                   5.70                   5.70
# 21  ...                  22.14                  22.14                  22.14
# 22  ...                  10.30                  10.30                  10.30
# 23  ...                   0.00                   0.00                   0.00
# 24  ...                   0.00                   0.00                   0.00
#
#     겸용도로(비분리형) 노선(개)_2018  겸용도로(비분리형) 노선(개)_2019  겸용도로(비분리형) 노선(개)_2020  \
# 0                      12                     11                     29
# 1                      11                     11                     27
# 2                       1                      1                      2
# 3                       8                      7                     14
# 4                       5                      4                      7
# 5                      16                     14                     35
# 6                       0                      0                     18
# 7                       3                      3                      8
# 8                       3                      3                      6
# 9                       2                      2                      5
# 10                      5                      4                      4
# 11                     13                     13                     14
# 12                      0                      0                      0
# 13                      2                      2                      4
# 14                      5                      5                      4
# 15                      6                      6                     11
# 16                      1                      1                      2
# 17                      4                      5                     29
# 18                     13                     13                     21
# 19                      9                      8                      9
# 20                      4                      7                      5
# 21                      6                      6                     12
# 22                      6                      6                      9
# 23                      0                      0                      0
# 24                      0                      0                      0
#
#     겸용도로(비분리형) 노선(개)_2021  겸용도로(비분리형) 노선(개)_2022  겸용도로(비분리형) 노선(개)_2023  \
# 0                      32                     39                     40
# 1                      39                     39                     42
# 2                       2                      2                      2
# 3                      11                     11                     11
# 4                       7                      7                      7
# 5                      32                     33                     34
# 6                      18                     18                     19
# 7                       8                      8                      8
# 8                       7                      7                      9
# 9                       5                      5                      5
# 10                      4                      4                      4
# 11                     14                     14                     14
# 12                      4                      4                      4
# 13                      4                      4                      4
# 14                      5                      5                      9
# 15                     10                     10                     13
# 16                      2                      2                      2
# 17                     30                     31                     33
# 18                     21                     26                     26
# 19                     10                     10                     11
# 20                      5                      5                      5
# 21                     13                     13                     13
# 22                     11                     11                     11
# 23                      0                      0                      0
# 24                      0                      0                      0
#
#     총계 연장(㎞)(2023-2022)
# 0                  2.90
# 1                  2.18
# 2                  0.00
# 3                  0.28
# 4                  0.00
# 5                  1.00
# 6                  5.07
# 7                  0.00
# 8                  0.28
# 9                  0.00
# 10                 0.62
# 11                 0.00
# 12                 0.00
# 13                 0.67
# 14                 3.17
# 15                 1.35
# 16                 0.00
# 17                 2.23
# 18                 0.00
# 19                 1.05
# 20                 0.00
# 21                 0.00
# 22                 0.00
# 23                 0.00
# 24                 0.00
#
# [25 rows x 74 columns]

# %%
df_parquet.columns
# Out:
# Index(['자치구', '총계 연장(㎞)_2018', '총계 연장(㎞)_2019', '총계 연장(㎞)_2020',
#        '총계 연장(㎞)_2021', '총계 연장(㎞)_2022', '총계 연장(㎞)_2023', '총계 노선(개)_2018',
#        '총계 노선(개)_2019', '총계 노선(개)_2020', '총계 노선(개)_2021', '총계 노선(개)_2022',
#        '총계 노선(개)_2023', '전용도로 연장(㎞)_2018', '전용도로 연장(㎞)_2019',
#        '전용도로 연장(㎞)_2020', '전용도로 연장(㎞)_2021', '전용도로 연장(㎞)_2022',
#        '전용도로 연장(㎞)_2023', '전용도로 노선(개)_2018', '전용도로 노선(개)_2019',
#        '전용도로 노선(개)_2020', '전용도로 노선(개)_2021', '전용도로 노선(개)_2022',
#        '전용도로 노선(개)_2023', '전용차로 연장(㎞)_2018', '전용차로 연장(㎞)_2019',
#        '전용차로 연장(㎞)_2020', '전용차로 연장(㎞)_2021', '전용차로 연장(㎞)_2022',
#        '전용차로 연장(㎞)_2023', '전용차로 노선(개)_2018', '전용차로 노선(개)_2019',
#        '전용차로 노선(개)_2020', '전용차로 노선(개)_2021', '전용차로 노선(개)_2022',
#        '전용차로 노선(개)_2023', '우선도로 연장(㎞)_2018', '우선도로 연장(㎞)_2019',
#        '우선도로 연장(㎞)_2020', '우선도로 연장(㎞)_2021', '우선도로 연장(㎞)_2022',
#        '우선도로 연장(㎞)_2023', '우선도로 노선(개)_2018', '우선도로 노선(개)_2019',
#        '우선도로 노선(개)_2020', '우선도로 노선(개)_2021', '우선도로 노선(개)_2022',
#        '우선도로 노선(개)_2023', '겸용도로(분리형) 연장(㎞)_2018', '겸용도로(분리형) 연장(㎞)_2019',
#        '겸용도로(분리형) 연장(㎞)_2020', '겸용도로(분리형) 연장(㎞)_2021', '겸용도로(분리형) 연장(㎞)_2022',
#        '겸용도로(분리형) 연장(㎞)_2023', '겸용도로(분리형) 노선(개)_2018', '겸용도로(분리형) 노선(개)_2019',
#        '겸용도로(분리형) 노선(개)_2020', '겸용도로(분리형) 노선(개)_2021', '겸용도로(분리형) 노선(개)_2022',
#        '겸용도로(분리형) 노선(개)_2023', '겸용도로(비분리형) 연장(㎞)_2018',
#        '겸용도로(비분리형) 연장(㎞)_2019', '겸용도로(비분리형) 연장(㎞)_2020',
#        '겸용도로(비분리형) 연장(㎞)_2021', '겸용도로(비분리형) 연장(㎞)_2022',
#        '겸용도로(비분리형) 연장(㎞)_2023', '겸용도로(비분리형) 노선(개)_2018',
#        '겸용도로(비분리형) 노선(개)_2019', '겸용도로(비분리형) 노선(개)_2020',
#        '겸용도로(비분리형) 노선(개)_2021', '겸용도로(비분리형) 노선(개)_2022',
#        '겸용도로(비분리형) 노선(개)_2023'],
#       dtype='object')

# %%
columns = ['자치구',
       '총계 연장(㎞)_2023', '전용도로 연장(㎞)_2023', '전용차로 연장(㎞)_2023', '우선도로 연장(㎞)_2023', '겸용도로(분리형) 연장(㎞)_2023', '겸용도로(비분리형) 연장(㎞)_2023', 
       '총계 노선(개)_2023', '전용도로 노선(개)_2023', '전용차로 노선(개)_2023', '우선도로 노선(개)_2023', '겸용도로(분리형) 노선(개)_2023', '겸용도로(비분리형) 노선(개)_2023'          
          ]
df_parquet2 = df_parquet[columns].head()

# %%
df_parquet2.sort_values(by = '총계 연장(㎞)_2023', ascending = False).head(10)
# Out:
#      자치구  총계 연장(㎞)_2023  총계 노선(개)_2023  전용도로 연장(㎞)_2023  전용도로 노선(개)_2023  \
# 0    강남구         113.39            117             8.80               11
# 17   송파구          99.72            193            21.04               48
# 3    강서구          77.34             86            32.17               36
# 1    강동구          76.62             99            17.59               19
# 12   마포구          67.40             63             6.20                7
# 19  영등포구          64.24             91             4.20                7
# 18   양천구          56.49             78            20.61               31
# 5    광진구          49.30             51             0.20                1
# 21   은평구          44.65             33             0.43                1
# 14   서초구          44.24             52             2.10                1
#
#     전용차로 연장(㎞)_2023  전용차로 노선(개)_2023  우선도로 연장(㎞)_2023  우선도로 노선(개)_2023  \
# 0              3.00                4             0.00                0
# 17             1.79                2             0.00                0
# 3              0.00                0             4.60                2
# 1              0.60                1             0.00                0
# 12             7.40               12            39.64               30
# 19            19.92               35            32.03               29
# 18             0.00                0             5.80                4
# 5              0.30                1             4.64                5
# 21             4.60                2             0.00                0
# 14             4.12                4             0.00                0
#
#     겸용도로(분리형) 연장(㎞)_2023  겸용도로(분리형) 노선(개)_2023  겸용도로(비분리형) 연장(㎞)_2023  \
# 0                  53.01                    62                  48.58
# 17                 63.62                   110                  13.27
# 3                  25.87                    37                  14.70
# 1                  15.53                    37                  42.90
# 12                 12.02                    10                   2.14
# 19                  2.29                     9                   5.80
# 18                  7.84                    17                  22.24
# 5                  12.13                    10                  32.03
# 21                 17.48                    17                  22.14
# 14                 30.75                    38                   7.27
#
#     겸용도로(비분리형) 노선(개)_2023
# 0                      40
# 17                     33
# 3                      11
# 1                      42
# 12                      4
# 19                     11
# 18                     26
# 5                      34
# 21                     13
# 14                      9
